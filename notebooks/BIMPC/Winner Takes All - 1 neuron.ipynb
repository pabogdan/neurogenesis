# %%
import spynnaker.pyNN as p
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from brian2.units import *

# %%
p.setup(timestep=1.0, min_delay=1.0, max_delay=144.0)
n_neurons = 1

# %%
run_time = 1000 * ms
f_p1 = 15 * Hz
f_p2 = 10 * Hz

# %%
cell_params_lif = {'cm': 0.25,
                   'i_offset': 0.0,
                   'tau_m': 20.0,
                   'tau_refrac': 2.0,
                   'tau_syn_E': 5.0,
                   'tau_syn_I': 5.0,
                   'v_reset': -70.0,
                   'v_rest': -65.0,
                   'v_thresh': -50.0
                   }

# %%
weight_to_spike = 2.
delay = 1

# %%
p1 = p.Population(n_neurons, p.IF_curr_exp, cell_params_lif,
                   label='pop_1')
p2 = p.Population(n_neurons, p.IF_curr_exp, cell_params_lif,
                   label='pop_2')

# %%
p.Projection(p1, p2, p.OneToOneConnector(weight_to_spike*2.0), target='inhibitory', label='inhib 1->2')
p.Projection(p2, p1, p.OneToOneConnector(weight_to_spike*2.0), target='inhibitory', label='inhib 2->1')
# Out:
# projection inhib 2->1

# %%
p.Projection(p1, p1, p.OneToOneConnector(weight_to_spike/1.3), label='excite 1->1')
p.Projection(p2, p2, p.OneToOneConnector(weight_to_spike/1.3), label='excite 2->2')
# Out:
# projection excite 2->2

# %%
p1.record_v()
p1.record_gsyn()
p1.record()
p2.record_v()
p2.record_gsyn()
p2.record()

# %%
# Input rates
p1_spike_times= np.linspace(0, run_time/ms, run_time * f_p1)
p2_spike_times= np.linspace(0, run_time/ms, run_time * f_p2)

t1 = p1_spike_times + run_time/ms
t2 = p2_spike_times + run_time/ms

spikeArray_p1 = {'spike_times': np.concatenate((p1_spike_times,t2))}
spikeArray_p2 = {'spike_times': np.concatenate((p2_spike_times,t1))}

# Input populations
input_p1 = p.Population(1, p.SpikeSourceArray, spikeArray_p1,label='inputSpikes_p1')
input_p2 = p.Population(1, p.SpikeSourceArray, spikeArray_p2,label='inputSpikes_p2')

# Input connections
p.Projection(input_p1, p1, p.OneToOneConnector(weight_to_spike), label='excite input_p1->1')
p.Projection(input_p2, p2, p.OneToOneConnector(weight_to_spike), label='excite input_p2->2')
# Out:
# projection excite input_p2->2

# %%
p.run(2 * run_time/ms)
# Out:
# Allocating virtual identifiers
# |0                           50%                         100%|
#  ============================================================
# Partitioning graph vertices
# |0                           50%                         100%|
#  ============================================================
# Partitioning graph edges
# |0                           50%                         100%|
#  ============================================================
# Generating partitioner report
# |0                           50%                         100%|
#  ============================================================
# Filtering edges
# |0                           50%                         100%|
#  ============================================================
# Placing graph vertices
# |0                           50%                         100%|
#  ========================================================================================================================
# Generating placement report
# |0                           50%                         100%|
#  ============================================================
# Generating placement by core report
# |0                           50%                         100%|
#  ============================================================
# Generating SDRAM usage report
# |0                           50%                         100%|
#  ============================================================
# Routing
# |0                           50%                         100%|
#  ============================================================
# Allocating tags
# |0                           50%                         100%|
#  ============================================================
# Reporting Tags
# |0                           50%                         100%|
#  ============================================================
# Getting the number of keys required by each edge using theapplication graph
# |0                           50%                         100%|
#  ============================================================
# Allocating routing keys
# |0                           50%                         100%|
#  ============================================================
# Generating Routing info report
# |0                           50%                         100%|
#  ============================================================
# Generating routing tables
# |0                           50%                         100%|
#  ============================================================
# Generating Router table report
# |0                           50%                         100%|
#  ============================================================
# Compressing routing Tables
# |0                           50%                         100%|
#  ============================================================
# Generating compressed router table report
# |0                           50%                         100%|
#  ============================================================
# Generating comparison of router table report
# |0                           50%                         100%|
#  ============================================================
# Generating sPyNNaker data specifications
# |0                           50%                         100%|
#  ============================================================
# Loading routing data onto the machine
# |0                           50%                         100%|
#  ============================================================
# Clearing tags
# |0                           50%                         100%|
#  ============================================================
# Loading Tags
# |0                           50%                         100%|
#  ============================================================
# Executing data specifications and loading data
# |0                           50%                         100%|
#  ============================================================
# Finding binaries
# |0                           50%                         100%|
#  ============================================================
# Loading executables onto the machine
# |0                           50%                         100%|
#  ============================================================
# Initialising buffers
# |0                           50%                         100%|
#  ============================================================
# Updating run time
# |0                           50%                         100%|
#  ============================================================
# Loading buffers (472 bytes)
# |0                           50%                         100%|
#  ============================================================

# %%
v_p1 = p1.get_v(compatible_output=True)
gsyn_p1 = p1.get_gsyn(compatible_output=True)
spikes_p1 = p1.getSpikes(compatible_output=True)
v_p2 = p2.get_v(compatible_output=True)
gsyn_p2 = p2.get_gsyn(compatible_output=True)
spikes_p2 = p2.getSpikes(compatible_output=True)
p.end()
# Out:
# Getting membrane voltage for pop_1
# |0                           50%                         100%|
#  ============================================================
# Getting conductance for pop_1
# |0                           50%                         100%|
#  ============================================================
# Getting spikes for pop_1
# |0                           50%                         100%|
#  ============================================================
# Getting membrane voltage for pop_2
# |0                           50%                         100%|
#  ============================================================
# Getting conductance for pop_2
# |0                           50%                         100%|
#  ============================================================
# Getting spikes for pop_2
# |0                           50%                         100%|
#  ============================================================
# Getting provenance data from machine graph
# |0                           50%                         100%|
#  ============================================================
# Getting provenance data
# |0                           50%                         100%|
#  ============================================================
# Getting Router Provenance
# |0                           50%                         100%|
#  ============================================================
# Extracting IOBUF
# |0                           50%                         100%|
#  ============================================================

# %%
if spikes_p1 is not None:
#     print spikes_p1
    plt.figure()
    plt.plot([i[1] for i in spikes_p1], [i[0] for i in spikes_p1], ".")
    plt.xlabel('Time/ms')
    plt.ylabel('spikes')
    plt.title('spikes')

# %%
if spikes_p2 is not None:
#     print spikes_p1
    plt.figure()
    plt.plot([i[1] for i in spikes_p2], [i[0] for i in spikes_p2], ".")
    plt.xlabel('Time/ms')
    plt.ylabel('spikes')
    plt.title('spikes')

# %%
fig = plt.figure(figsize=(16,8))
plt.plot(v_p1[:, 2], c='b')
plt.plot(v_p2[:, 2], c='r')
for t in spikes_p1[:, 1]:
    plt.axvline(t, ls='-', c='b', lw=1, alpha=.5)
for t in spikes_p2[:, 1]:
    plt.axvline(t, ls=':', c='r', lw=1, alpha=.7)
    
plt.axvline(run_time/ms, ls='-', c='g', lw=1, alpha=1)
plt.axvline(2*run_time/ms, ls='-', c='g', lw=1, alpha=1)
plt.xlabel('Time/ms')
plt.ylabel('mV')
plt.title('Voltage')

# %%
fig = plt.figure(figsize=(16,8))
plt.plot([i[1] for i in spikes_p1], [i[0] for i in spikes_p1], ".", c='b')
plt.plot([i[1] for i in spikes_p2], [i[0] for i in spikes_p2], ".", c='r')
plt.axvline(run_time/ms, ls='-', c='g', lw=1, alpha=1)
plt.axvline(2*run_time/ms, ls='-', c='g', lw=1, alpha=1)
plt.xlabel('Time/ms')
plt.ylabel('spikes')
plt.title('spikes - 10 neurons')
